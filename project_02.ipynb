# %% [markdown]
# <a href="https://colab.research.google.com/github/ravimanoj116-stack/localrepo/blob/main/project_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

print("Movie Recommendation Project Started")
# Out:
# Movie Recommendation Project Started
