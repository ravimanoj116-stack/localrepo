# %% [markdown]
# <a href="https://colab.research.google.com/github/ravimanoj116-stack/localrepo/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello GitHub")
# Out:
# Hello GitHub

# %%
a = 10
b = 20

print("Sum =", a + b)
# Out:
# Sum = 30
